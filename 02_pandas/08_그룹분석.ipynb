# %% [markdown]
# #### 데이터프레임 그룹 분석

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ##### pivot 메서드

# %%
data = {
     "도시":["서울","서울","서울","부산","부산","부산","인천","인천"],
     "연도":["2015","2010","2005","2015","2010","2005","2015","2010"],
     "인구":[9904312, 9631482, 9762546, 3448737, 3393191, 3512547, 2890451, 2632035]     
 }
 
columns = ["도시","연도","인구"]
df1 = pd.DataFrame(data=data, columns=columns)
print(df1)
# Out:
#    도시    연도       인구
# 0  서울  2015  9904312
# 1  서울  2010  9631482
# 2  서울  2005  9762546
# 3  부산  2015  3448737
# 4  부산  2010  3393191
# 5  부산  2005  3512547
# 6  인천  2015  2890451
# 7  인천  2010  2632035

# %%
df1.columns
# Out:
# Index(['도시', '연도', '인구'], dtype='object')

# %%
def cityToMetro(c):
    if(c in ["서울", "인천"]): return "수도권"
    elif(c in ["부산"]): return "경상권"

# %%
df1["지역"] = df1.apply(lambda x : cityToMetro(x["도시"]), axis=1)

# %%
df1
# Out:
#    도시    연도       인구   지역
# 0  서울  2015  9904312  수도권
# 1  서울  2010  9631482  수도권
# 2  서울  2005  9762546  수도권
# 3  부산  2015  3448737  경상권
# 4  부산  2010  3393191  경상권
# 5  부산  2005  3512547  경상권
# 6  인천  2015  2890451  수도권
# 7  인천  2010  2632035  수도권

# %%
# 행 인덱스, 열 인덱스, 데이터
df1.pivot(index='도시', columns='연도', values='인구')
# Out:
# 연도       2005       2010       2015
# 도시
# 부산  3512547.0  3393191.0  3448737.0
# 서울  9762546.0  9631482.0  9904312.0
# 인천        NaN  2632035.0  2890451.0

# %%
df1.pivot(index=['지역','도시'], columns='연도', values='인구')
# Out:
# 연도           2005       2010       2015
# 지역  도시
# 경상권 부산  3512547.0  3393191.0  3448737.0
# 수도권 서울  9762546.0  9631482.0  9904312.0
#     인천        NaN  2632035.0  2890451.0

# %% [markdown]
# ##### 그룹 분석

# %%
iris = sns.load_dataset('iris')
iris.info()
iris
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# species별로 sepal_length, sepal_width, petal_length, petal_width의 평균을 구하기
iris.groupby(by='species').mean().round(2)
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa              5.01         3.43          1.46         0.25
# versicolor          5.94         2.77          4.26         1.33
# virginica           6.59         2.97          5.55         2.03

# %%
# species별로 각 속성의 평균, 표준편차를 구하기
iris.groupby(by='species').agg(func=['mean', 'median', 'std']).round(2)
# Out:
#            sepal_length              sepal_width              petal_length  \
#                    mean median   std        mean median   std         mean
# species
# setosa             5.01    5.0  0.35        3.43    3.4  0.38         1.46
# versicolor         5.94    5.9  0.52        2.77    2.8  0.31         4.26
# virginica          6.59    6.5  0.64        2.97    3.0  0.32         5.55
#
#                         petal_width
#            median   std        mean median   std
# species
# setosa       1.50  0.17        0.25    0.2  0.11
# versicolor   4.35  0.47        1.33    1.3  0.20
# virginica    5.55  0.55        2.03    2.0  0.27

# %% [markdown]
# ##### bt_df.csv 불러와서 groupby 이용해서 분석하기

# %%
filepath = '../bt_df.csv'
df1 = pd.read_csv(filepath)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          100 non-null    object
#  1   sex           100 non-null    object
#  2   age           78 non-null     float64
#  3   blood         93 non-null     object
#  4   country       93 non-null     object
#  5   math          88 non-null     float64
#  6   verbal        86 non-null     float64
#  7   python        85 non-null     float64
#  8   target        100 non-null    object
#  9   passed        100 non-null    int64
#  10  review        100 non-null    object
#  11  review_score  100 non-null    float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 9.5+ KB

# %%
cols = ['sex','age','blood','country','math','verbal','python', 'passed', 'review_score']
df1 = df1[cols]
df1.tail()
# Out:
#        sex   age blood country  math  verbal  python  passed  review_score
# 95    male   NaN     B     USA  83.0     NaN     NaN       0           6.9
# 96    male  71.0     A     USA   NaN    70.0   62.25       0           1.5
# 97    male  23.0     A   Korea  84.0    63.0   74.51       0           4.0
# 98  female  34.0     O     USA  55.0    58.0   91.67       0           2.4
# 99    male  34.0     A     NaN  88.0    91.0   87.75       0           3.4

# %%
# 나라별로 math, verbal, python 성적의 평균, 중간값, 표준편차 구하기
df1.groupby(by='country')[['math', 'verbal', 'python']].agg(func=['mean','median','std']).round(2)
# Out:
#           math               verbal               python
#           mean median    std   mean median    std   mean median    std
# country
# Japan    68.92   73.0  16.95  71.42   72.5  13.55  67.60  70.59  16.18
# Korea    66.42   60.0  18.83  76.00   80.0  11.61  68.24  68.38  14.07
# USA      72.08   72.0  16.13  70.20   68.0  14.33  64.40  58.33  15.00

# %%
df2 = pd.DataFrame(data={'key1':["A","A","B","B","A"],
                         'key2':["one","two","one","two","one"],
                         'data1':[1,2,3,4,5],
                         'data2':[10,20,30,40,50]})
df2
# Out:
#   key1 key2  data1  data2
# 0    A  one      1     10
# 1    A  two      2     20
# 2    B  one      3     30
# 3    B  two      4     40
# 4    A  one      5     50

# %%
df2.groupby(by='key1').sum()
# Out:
#       data1  data2
# key1
# A         8     80
# B         7     70

# %%
df2.groupby(by='key1')['data2'].sum()
# Out:
# key1
# A    80
# B    70
# Name: data2, dtype: int64

# %%
df2.data2.groupby(df2.key1).sum()
# Out:
# key1
# A    80
# B    70
# Name: data2, dtype: int64

# %% [markdown]
# ##### 내가 만든 함수 적용하기

# %%
def peak_to_peak_ratio(x):
    return x.max() / x.min()

# %%
iris.groupby(by='species').agg(func=peak_to_peak_ratio).round(2)
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa              1.35         1.91          1.90         6.00
# versicolor          1.43         1.70          1.70         1.80
# virginica           1.61         1.73          1.53         1.79

# %%
df1.groupby(by='country')[['math','verbal','python']].agg(func=peak_to_peak_ratio).round(2)
# Out:
#          math  verbal  python
# country
# Japan    2.45    1.88    2.10
# Korea    2.38    1.77    2.01
# USA      2.48    1.90    2.09

# %%
df1.groupby(by='country')[['math','verbal','python']].agg(func=lambda x:x.max()/x.min()).round(2)
# Out:
#          math  verbal  python
# country
# Japan    2.45    1.88    2.10
# Korea    2.38    1.77    2.01
# USA      2.48    1.90    2.09

# %%
df1.groupby(by='country')[['math','verbal','python']].apply(lambda x : x.max()/x.min()).round(2)
# Out:
#          math  verbal  python
# country
# Japan    2.45    1.88    2.10
# Korea    2.38    1.77    2.01
# USA      2.48    1.90    2.09

# %%
df1.groupby(by='country').describe().round(2)
# Out:
#           age                                                math         ...  \
#         count   mean    std   min    25%   50%    75%   max count   mean  ...
# country                                                                   ...
# Japan    22.0  24.11  10.05  2.00  20.25  25.5  28.88  49.0  24.0  68.92  ...
# Korea    18.0  24.83  16.74  4.00  14.25  22.0  30.50  65.0  19.0  66.42  ...
# USA      31.0  29.67  17.39  0.83  18.50  29.0  38.00  71.0  39.0  72.08  ...
#
#         passed      review_score
#            75%  max        count  mean   std  min   25%   50%   75%   max
# country
# Japan      0.0  0.0         26.0  5.72  2.08  1.0  4.22  6.05  6.95  10.0
# Korea      1.0  1.0         23.0  4.74  2.64  0.2  3.30  4.80  6.70   9.8
# USA        0.0  0.0         44.0  4.76  2.64  0.4  2.80  4.35  6.90   9.9
#
# [3 rows x 48 columns]

# %%
df1.groupby(by='country').describe().round(2).T
# Out:
# country             Japan  Korea    USA
# age          count  22.00  18.00  31.00
#              mean   24.11  24.83  29.67
#              std    10.05  16.74  17.39
#              min     2.00   4.00   0.83
#              25%    20.25  14.25  18.50
#              50%    25.50  22.00  29.00
#              75%    28.88  30.50  38.00
#              max    49.00  65.00  71.00
# math         count  24.00  19.00  39.00
#              mean   68.92  66.42  72.08
#              std    16.95  18.83  16.13
#              min    40.00  40.00  40.00
#              25%    54.25  53.00  60.00
#              50%    73.00  60.00  72.00
#              75%    81.00  83.50  84.50
#              max    98.00  95.00  99.00
# verbal       count  24.00  20.00  35.00
#              mean   71.42  76.00  70.20
#              std    13.55  11.61  14.33
#              min    50.00  53.00  50.00
#              25%    61.50  67.00  58.50
#              50%    72.50  80.00  68.00
#              75%    81.50  85.25  84.50
#              max    94.00  94.00  95.00
# python       count  23.00  20.00  35.00
#              mean   67.60  68.24  64.40
#              std    16.18  14.07  15.00
#              min    44.12  45.59  44.12
#              25%    50.49  56.49  52.94
#              50%    70.59  68.38  58.33
#              75%    80.39  77.20  77.69
#              max    92.65  91.67  92.16
# passed       count  26.00  23.00  44.00
#              mean    0.00   0.39   0.00
#              std     0.00   0.50   0.00
#              min     0.00   0.00   0.00
#              25%     0.00   0.00   0.00
#              50%     0.00   0.00   0.00
#              75%     0.00   1.00   0.00
#              max     0.00   1.00   0.00
# review_score count  26.00  23.00  44.00
#              mean    5.72   4.74   4.76
#              std     2.08   2.64   2.64
#              min     1.00   0.20   0.40
#              25%     4.22   3.30   2.80
#              50%     6.05   4.80   4.35
#              75%     6.95   6.70   6.90
#              max    10.00   9.80   9.90

# %% [markdown]
# ##### mpg 데이터셋

# %%
mpg = sns.load_dataset('mpg')
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name manufacturer
# 0          70    usa  chevrolet chevelle malibu    chevrolet
# 1          70    usa          buick skylark 320        buick
# 2          70    usa         plymouth satellite     plymouth
# 3          70    usa              amc rebel sst          amc
# 4          70    usa                ford torino         ford

# %%
mpg.name.apply(lambda x : ' '.join(x.split(' ')[1:]))
# Out:
# 0      chevelle malibu
# 1          skylark 320
# 2            satellite
# 3            rebel sst
# 4               torino
#             ...
# 393         mustang gl
# 394             pickup
# 395            rampage
# 396             ranger
# 397               s-10
# Name: name, Length: 398, dtype: object

# %%
mpg['manufacturer'] = mpg.name.apply(lambda x : x.split(' ')[0])
mpg['model'] = mpg.name.apply(lambda x : ' '.join(x.split(' ')[1:]) if len(x.split(' ')) > 1 else np.nan)

# %%
mpg[['name', 'manufacturer', 'model']]
# Out:
#                           name manufacturer            model
# 0    chevrolet chevelle malibu    chevrolet  chevelle malibu
# 1            buick skylark 320        buick      skylark 320
# 2           plymouth satellite     plymouth        satellite
# 3                amc rebel sst          amc        rebel sst
# 4                  ford torino         ford           torino
# ..                         ...          ...              ...
# 393            ford mustang gl         ford       mustang gl
# 394                  vw pickup           vw           pickup
# 395              dodge rampage        dodge          rampage
# 396                ford ranger         ford           ranger
# 397                 chevy s-10        chevy             s-10
#
# [398 rows x 3 columns]

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
#  9   manufacturer  398 non-null    object
#  10  model         396 non-null    object
# dtypes: float64(4), int64(3), object(4)
# memory usage: 34.3+ KB

# %%
def q3cut(s):
    return pd.qcut(x=s, q=3, labels=['소','중','대']).astype(str)

# %%
iris["petal_length_class"] = iris.groupby(by='species')["petal_length"].apply(q3cut)

# %%
# transform 메서드 이용하기
iris["sepal_width_class"] = iris.groupby(by='species')['sepal_width'].transform(q3cut)

# %%
iris[['petal_length', 'petal_length_class', 'sepal_width', 'sepal_width_class']].tail(10)
# Out:
#      petal_length petal_length_class  sepal_width sepal_width_class
# 140           5.6                  중          3.1                 대
# 141           5.1                  소          3.1                 대
# 142           5.1                  소          2.7                 소
# 143           5.9                  대          3.2                 대
# 144           5.7                  중          3.3                 대
# 145           5.2                  소          3.0                 중
# 146           5.0                  소          2.5                 소
# 147           5.2                  소          3.0                 중
# 148           5.4                  중          3.4                 대
# 149           5.1                  소          3.0                 중
